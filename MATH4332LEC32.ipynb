# %% [markdown]
# **Numerical Integration**

# %% [markdown]
# **Motivation**
#
# The integral of a function is normally described as the “area under the curve.” In engineering and science, the integral has many applications for modeling, predicting, and understanding physical systems. However in practice, finding an exact solution for the integral of a function is difficult or impossible.
#
# This chapter describes several methods of numerically integrating functions. By the end of this chapter, you should understand these methods, how they are derived, their geometric interpretation, and their accuracy.

# %% [markdown]
# **Numerical Integration Problem Statement**
#
# Given a function $f(x)$, we want to approximate the integral of $f(x)$ over the total interval, $[a,b]$. The following figure illustrates this area. To accomplish this goal, we assume that the interval has been discretized into a numeral grid, $x$, consisting of $n+1$ points with spacing, $h=\dfrac{b-a}{n}$. Here, we denote each point in $x$, by $x_i$, where $x_0=a$ and $x_n=b$. Note: There are $n+1$ grid points because the count starts at $x_0$. We also assume we have a function, $f(x)$, that can be computed for any of the grid points, or that we have been given the function implicitly as $f(x_i)$. The interval $[x_i,x_{i+1}]$ is referred to as a **subinterval**.
#
# ![Screenshot 2024-11-09 at 4.47.24 AM.png](data:image/png;base64,...)
#
# The following sections give some of the most common methods of approximating $\int_{a}^{b}f(x)dx$. Each method approximates the area under $f(x)$ for each subinterval by a shape for which it is easy to compute the exact area, and then sums the area contributions of every subinterval.

# %% [markdown]
# **Riemann's Integral**
#
# The simplest method for approximating integrals is by summing the area of rectangles that are defined for each subinterval. The width of the rectangle is $x_{i+1}-x_i=h$, and the height is defined by a function value $f(x)$ for some $x$ in the subinterval. An obvious choice for the height is the function value at the left endpoint, $x_i$, or the right endpoint, $x_{i+1}$, because these values can be used even if the function itself is not known. This method gives the Riemann Integral approximation, which is
# $$\int_{a}^{b}f(x)dx ≈ \sum_{i=0}^{n-1}hf(x_i)dx$$
# or
# $$\int_{a}^{b}f(x)dx ≈ \sum_{i=1}^{n}hf(x_i)dx$$
# depending on whether the left or right endpoint is chosen.
#
# As with numerical differentiation, we want to characterize how the accuracy improves as $h$ gets small. To determine this characterizing, we first rewrite the integral of $f(x)$ over an arbitrary subinterval in terms of the Taylor series. The Taylor series of $f(x)$ around $a=x_i$ is
# $$f(x)=f(x_i)+f^{\prime}(x_i)(x-x_i)+\cdots$$
# Thus
# $$\int_{x_i}^{x_{i+1}}f(x)dx =\int_{x_i}^{x_{i+1}}\left(f(x_i)+f^{\prime}(x_i)(x-x_i)+\cdots\right) dx$$
# by substitution of the Taylor series for the function. Since the integral distributes, we can rearrange the right side into the following form:
# $$\int_{x_i}^{x_{i+1}} f(x_i) dx + \int_{x_i}^{x_{i+1}} f^{\prime}(x_i)(x-x_i)dx + \cdots.$$
# Solving each integral separately results in the approximation
# $$\int_{x_i}^{x_{i+1}}f(x)dx =hf(x_i)+\dfrac{h^2}{2}f^{\prime}(x_i)+O(h^3),$$
# which is just
# $$\int_{x_i}^{x_{i+1}}f(x)dx =hf(x_i)+O(h^2).$$
# Since the $hf(x_i)$ term is our Riemann integral approximation for a single subinterval, the Riemann integral approximation over a single interval is $O(h^2)$.
#
# If we sum the $O(h^2)$ error over the entire Riemann sum, we get $nO(h^2)$. The relationship between $n$ and $h$ is
# $$h=\dfrac{b-a}{n}$$
# and so our total error becomes $\dfrac{b-a}{n} O(h^2)=O(h)$ over the whole interval. Thus the overall accuracy is $O(h)$.
#
# The **Midpoint Rule** takes the rectangle height of the rectangle at each subinterval to be the function value at the midpoint between $x_i$
#  and  $x_{i+1}$, which for compactness we denote by $y_i=\dfrac{x_{i+1}+x_{i}}{2}$. The Midpoint Rule says
#  $$\int_{a}^{b}f(x)dx ≈ \sum_{i=0}^{n-1}hf(y_i)dx$$
#  Similarly to the Riemann integral, we take the Taylor series of $f(x)$ around $y_i$, which is
#  $$f(x)=f(y_i) + f^{\prime}(y_i)(x-y_i)+ \dfrac{f^{\prime\prime}(y_i)(x-y_i)^2}{2!} +\cdots$$
#  Then the integral over a subinterval is
#  $$\int_{x_i}^{x_{i+1}}f(x)dx=\int_{x_i}^{x_{i+1}}\left( f(y_i) + f^{\prime}(y_i)(x-y_i)+ \dfrac{f^{\prime\prime}(y_i)(x-y_i)^2}{2!} +\cdots\right),$$
#  which distributes to
#  $$\int_{x_i}^{x_{i+1}}f(x)dx=\int_{x_i}^{x_{i+1}} f(y_i)dx + \int_{x_i}^{x_{i+1}} f^{\prime}(y_i)(x-y_i)dx + \int_{x_i}^{x_{i+1}} \dfrac{f^{\prime\prime}(y_i)(x-y_i)^2}{2!} +\cdots.$$
#
#  Recognizing that since $x_i$ and $x_{i+1}$ are symmetric around $y_i$ then $\int_{x_i}^{x_{i+1}} f^{\prime}(y_i)(x-y_i)=0dx$. This is true for the integral of $(x-y_i)^p$ for any odd $p$. For the integral of $(x-y_i)^p$
#  and with $p$ even, it suffices to say that $$\int_{x_i}^{x_{i+1}}(x-y_i)^pdx=\int_{-\dfrac{h}{2}}^{\dfrac{h}{2}}x^pdx$$ which will result in some multiple of $h^{p+1}$ with no lower order powers of $h$.
#
# Utilizing these facts reduces the expression for the integral of $f(x)$ to
# $$\int_{x_i}^{x_{i+1}}f(x)dx=hf(y_i)+O(h^3)$$
# Since $hf(y_i)$ is the approximation of the integral over the subinterval, the Midpoint Rule is $O(h^3)$ for one subinterval, and using similar arguments as for the Riemann Integral, is $O(h^2)$ over the whole interval. Since the Midpoint Rule requires the same number of calculations as the Riemann Integral, we essentially get an extra order of accuracy for free! However, if $f(x_i)$
#  is given in the form of data points, then we will not be able to compute $f(y_i)$ for this integration scheme.

# %% [markdown]
# **Ex:**
#
# Use the left Riemann Integral, right Riemann Integral, and Midpoint Rule to approximate $\int_0^\pi \sin(x)dx$ wtih $11$ evenly spaced grid ponts over the whole interval. Compare this value to the exact value of $2$.

# %%
import numpy as np

a = 0
b = np.pi
n = 11
h = (b - a) / (n - 1)
x = np.linspace(a, b, n)
f = lambda y: np.sin(y)

I_riemannL = h * sum(f(x[:n-1:]))
err_riemannL = 2 - I_riemannL

I_riemannR = h * sum(f(x[1::]))
err_riemannR = 2 - I_riemannR

I_mid = h * sum(f((x[:n-1] + x[1:])/2))
err_mid = 2 - I_mid

print(I_riemannL)
print(err_riemannL)

print(I_riemannR)
print(err_riemannR)

print(I_mid)
print(err_mid)
# Out:
# 1.9835235375094546
# 0.01647646249054535
# 1.9835235375094546
# 0.01647646249054535
# 2.0082484079079745
# -0.008248407907974542

# %%
# Or we can define f as an array

# %%
import numpy as np

a = 0
b = np.pi
n = 11
h = (b - a) / (n - 1)
x = np.linspace(a, b, n)
f = np.sin(x)

I_riemannL = h * sum(f[:n-1:])
err_riemannL = 2 - I_riemannL

I_riemannR = h * sum(f[1::])
err_riemannR = 2 - I_riemannR

I_mid = h * sum(np.sin((x[:n-1] + x[1:])/2))
err_mid = 2 - I_mid

print(I_riemannL)
print(err_riemannL)

print(I_riemannR)
print(err_riemannR)

print(I_mid)
print(err_mid)
# Out:
# 1.9835235375094546
# 0.01647646249054535
# 1.9835235375094546
# 0.01647646249054535
# 2.0082484079079745
# -0.008248407907974542

# %% [markdown]
# **Trapezoid Rule**
#
# The **Trapezoid Rule** fits a trapezoid into each subinterval and sums the areas of the trapezoid to approximate the total integral. This approximation for the integral to an arbitrary function is shown in the following figure. For each subinterval, the Trapezoid Rule computes the area of a trapezoid with corners at $(x_i,0)$, $(x_{i+1},0)$, $(x_i,f(x_i))$, and $\left(x_{i+1},f(x_{i+1})\right)$, which is $h\dfrac{f(x_i)+f(x_{i+1})}{2}$. Thus, the Trapezoid Rule approximates integrals according to the expression
# $$\int_{a}^{b}f(x)dx≈\sum_{i=0}^{n-1}h\dfrac{f(x_i)+f(x_{i+1})}{2}$$
#
# ![Screenshot 2024-11-09 at 5.56.06 AM.png](data:image/png;base64,...)

# %% [markdown]
# **Ex:**
#
# You may notice that the Trapezoid Rule "double-counts" most of the terms in the series. To illustrate this fact, consider the expansion of the Trapezoid Rule:
#
# $$\sum_{i=0}^{n-1}h\dfrac{f(x_i)+f(x_{i+1})}{2}=\dfrac{h}{2}\left[(f(x_0)+f(x_1))+(f(x_1)+f(x_2))+\cdots+(f(x_{n-2})+f(x_{n-1}))+ (f(x_{n-1})+f(x_{n}))\right]$$
#
# Computationally, this is many extra additions and calls to $f(x)$ than is really necessary. We can be more computationally efficient using the following expression.
# $$\int_{a}^{b}f(x)dx≈\dfrac{h}{2}\left(f(x_0)+2\sum_{i=1}^{n-1}f(x_i)+f(x_{n}))\right)$$
# To determine the accuracy of the Trapezoid Rule approximation, we first take Taylor series expansion of $f(x)$ around $y_i=\dfrac{x_i+x_{i+1}}{2}$ which is the midpoint between $x_i$ and $x_{i+1}$. This Taylor series expansion is
# $$f(x)=f(y_i) + f^{\prime}(y_i)(x-y_i)+ \dfrac{f^{\prime\prime}(y_i)(x-y_i)^2}{2!} +\cdots$$
# Computing the Taylor series at $x_i$ and $x_{i+1}$ and noting that $x_i-y_{i}=-\dfrac{h}{2}$ and $x_{i+1}-y_i=\dfrac{h}{2}$
# , results in the following expressions:
# $$f(x_i)=f(y_i) - h\dfrac{f^{\prime}(y_i)}{2}+ h^2\dfrac{f^{\prime\prime}(y_i)}{8} -\cdots$$
# and
# $$f(x_{i+1})=f(y_i) + h\dfrac{f^{\prime}(y_i)}{2}+ h^2\dfrac{f^{\prime\prime}(y_i)}{8} +\cdots$$
# Taking the average of these two expressions results in the new expression,
# $$\dfrac{f(x_i)+f(x_{i+1})}{2}=f(y_i)+O(h^2).$$
# Solving this expression for $f(y_i)$ yields
# $$f(y_i)=\dfrac{f(x_i)+f(x_{i+1})}{2}+O(h^2).$$
# Now returning to the Taylor expansion for $f(x)$, the integral of $f(x)$ over a subinterval is
# $$\int_{x_i}^{x_{i+1}}f(x)dx=\int_{x_i}^{x_{i+1}}\left( f(y_i) + f^{\prime}(y_i)(x-y_i)+ \dfrac{f^{\prime\prime}(y_i)(x-y_i)^2}{2!} +\cdots\right),$$
#
# Distributing the integral results in the expression
#  $$\int_{x_i}^{x_{i+1}}f(x)dx=\int_{x_i}^{x_{i+1}} f(y_i)dx + \int_{x_i}^{x_{i+1}} f^{\prime}(y_i)(x-y_i)dx + \int_{x_i}^{x_{i+1}} \dfrac{f^{\prime\prime}(y_i)(x-y_i)^2}{2!} +\cdots.$$
#  Now since $x_i$ and $x_{i+1}$ are symmetric around $y_i$, the integrals of the odd powers of $(x-y_i)^p$ disappear and the even powers resolve to a multiple $h^{p+1}$.
#  $$\int_{x_i}^{x_{i+1}}f(x)dx=hf(y_i)+O(h^3)$$
#  Now if we substitute $f(y_i)$ with the expression derived explicitly in terms of $f(x_i)$ and $f(x_{i+1})$, we get
#  $$\int_{x_i}^{x_{i+1}}f(x)dx=h\left(\dfrac{f(x_i)+f(x_{i+1})}{2}+O(h^2)\right)+O(h^3),$$
#  which is equivalent to
# $$\int_{x_i}^{x_{i+1}}f(x)dx=h\left(\dfrac{f(x_i)+f(x_{i+1})}{2}\right)+hO(h^2)+O(h^3),$$
# and therefore
# $$\int_{x_i}^{x_{i+1}}f(x)dx=h\left(\dfrac{f(x_i)+f(x_{i+1})}{2}\right)+O(h^3)$$
# Since $\dfrac{1}{2}\left(f(x_i)+f(x_{i+1})\right)$  is the Trapezoid Rule approximation for the integral over the subinterval, it is $O(h^3)$ for a single subinterval and $O(h^2)$ over the whole interval.

# %% [markdown]
# **Ex:**
#
# Use the Trapezoid Rule to approximate $\int_{0}^{\pi}\sin(x)dx$ with $11$ evenly spaced grid points over the whole interval. Compare this value to the exact value of $2$.

# %%
import numpy as np

a = 0
b = np.pi
n = 11
h = (b - a) / (n - 1)
x = np.linspace(a, b, n)
f = lambda z: np.sin(z)

I_trap = (h/2)*(f(x[0]) + 2 * sum(f(x[1:n-1])) + f(x[n-1]))
err_trap = 2 - I_trap

print(I_trap)
print(err_trap)
# Out:
# 1.9835235375094546
# 0.01647646249054535

# %%
# Or we can define f as an array

# %%
import numpy as np

a = 0
b = np.pi
n = 11
h = (b - a) / (n - 1)
x = np.linspace(a, b, n)
f = np.sin(x)

I_trap = (h/2)*(f[0] + 2 * sum(f[1:n-1]) + f[n-1])
err_trap = 2 - I_trap

print(I_trap)
print(err_trap)
# Out:
# 1.9835235375094546
# 0.01647646249054535

# %% [markdown]
# **Simpson's Rule**
#
# Consider two consecutive subintervals, $[x_{i-1},x_{i}]$ and $[x_{i},x_{i+1}]$. Simpson's Rule approximates the area under $f(x)$ over these two subintervals by fitting a quadratic polynomial through the points $(x_{i-1},f(x_{i-1}))$, $(x_i,f(x_i))$, and $(x_{i+1},f(x_{i+1}))$, which is a unique polynomial, and then integrating the quadratic exactly. The following shows this integral approximation for an arbitrary function.
#
# ![Screenshot 2024-11-09 at 7.34.08 AM.png](data:image/png;base64,...)
#
# First, we construct the quadratic polynomial approximation of the function over the two subintervals. The easiest way to do this is to use Lagrange polynomials, which was discussed earlier. By applying the formula for constructing Lagrange polynomials we get the polynomial
# $$L_i(x)=f(x_{i-1})\dfrac{(x-x_i)(x-x_{i+1})}{(x_{i-1}-x_{i})(x_{i-1}-x_{i+1})}+f(x_{i})\dfrac{(x-x_{i-1})(x-x_{i+1})}{(x_{i}-x_{i-1})(x_{i}-x_{i+1})}+ f(x_{i+1})\dfrac{(x-x_{i-1})(x-x_i)}{(x_{i+1}-x_{i-1})(x_{i+1}-x_{i})}$$
# and with substitutions for $h$ results in
# $$L_i(x)=\dfrac{f(x_{i-1})}{2h^2}\left(x-x_i \right) \left(x-x_{i+1} \right)-\dfrac{f(x_{i})}{h^2}\left(x-x_{i-1}\right)\left(x-x_{i+1}\right)+ \dfrac{f(x_{i+1})}{2h^2}\left(x-x_{i-1}\right)\left(x-x_i\right)$$
# You can confirm that the polynomial intersects the desired points. With some algebra and manipulation, the integral of $L_i(x)$ over the two subintervals is
# $$\int_{x_{i-1}}^{x_{i+1}}L_i(x)dx=\dfrac{h}{3}\left(f(x_{i-1})+4f(x_i)+f(x_{i+1})\right).$$
# To approximate the integral over $(a,b)$, we must sum the integrals of $L_i(x)$ over every two subintervals since $L_i(x)$ spans two subintervals. Substituting $\dfrac{h}{3}\left(f(x_{i-1})+4f(x_i)+f(x_{i+1})\right)$ for the integral of $L_i(x)$ and regrouping the terms for efficiency leads to the formula
# $\large\int_{a}^{b}f(x)dx≈\dfrac{h}{3}\left[ f(x_0) + 4\left(\sum_{i=1,\,i\,odd}^{n-1}f(x_i)\right)+2\left(\sum_{i=2,\,i\,even}^{n-2}f(x_i)\right)+f(x_{n})\right]$
# This regrouping is illustrated in the figure below:
#
# ![Screenshot 2024-11-09 at 8.16.57 AM.png](data:image/png;base64,...)
#
# **WARNING**! Note that to use Simpson's Rule, you must have an even number of intervals and, therefore, an odd number of grid points.
#
# To compute the accuracy of the Simpson's Rule, we take the Taylor series approximation of $f(x)$ around $x_i$, which is
# $$f(x)=f(x_i)+f^{\prime}(x_i)(x-x_i)+\dfrac{f^{\prime\prime}(x_i)(x-x_i)^2}{2!}+\dfrac{f^{\prime\prime\prime}(x_i)(x-x_i)^3}{3!}+\dfrac{f^{\prime\prime\prime\prime}(x_i)(x-x_i)^4}{4!}+\cdots$$
# Computing the Taylor series at $x_{i-1}$ and $x_{i+1}$ and substituting for $h$ where appropriate gives the expressions
# $$f(x_{i-1})=f(x_{i})-hf^{\prime}(x_i)+\dfrac{h^2f^{\prime\prime}(x_i)}{2!}-\dfrac{h^3f^{\prime\prime\prime}(x_i)}{3!}+\dfrac{h^4f^{\prime\prime\prime\prime}(x_i)}{4!}-\cdots$$
# and
# $$f(x_{i+1})=f(x_{i})+hf^{\prime}(x_i)+\dfrac{h^2f^{\prime\prime}(x_i)}{2!}+\dfrac{h^3f^{\prime\prime\prime}(x_i)}{3!}+\dfrac{h^4f^{\prime\prime\prime\prime}(x_i)}{4!}+\cdots$$
# Now consider the expression $\dfrac{f(x_{i-1})+4f(x_i)+f(x_{i+1})}{6}$. Substituting the Taylor series for the respective numerator values produces the equation
# $$\dfrac{f(x_{i-1})+4f(x_i)+f(x_{i+1})}{6}=f(x_i)+\dfrac{h^2}{6}f^{\prime\prime}(x_i)+\dfrac{h^4}{72}f^{\prime\prime\prime}(x_i)+\cdots$$
# Note that the odd terms cancel out. This implies
# $$f(x_i)=\dfrac{f(x_{i-1})+4f(x_i)+f(x_{i+1})}{6}-\dfrac{h^2}{6}f^{\prime\prime}(x_i)+O(h^4).$$
# By substitution of the Taylor series for $f(x)$, the integral of $f(x)$ over two subintervals is then
# $$\int_{x_{i-1}}^{x_{i+1}}f(x)dx=\int_{x_{i-1}}^{x_{i+1}}\left( f(x_i)+f^{\prime}(x_i)(x-x_i)+\dfrac{f^{\prime\prime}(x_i)(x-x_i)^2}{2!}+\dfrac{f^{\prime\prime\prime}(x_i)(x-x_i)^3}{3!}+\dfrac{f^{\prime\prime\prime\prime}(x_i)(x-x_i)^4}{4!}+\cdots\right).$$
# Again, we distribute the integral and without showing it, we drop the integrals of terms with odd powers because they are zero.
# $$\int_{x_{i-1}}^{x_{i+1}}f(x)dx=\int_{x_{i-1}}^{x_{i+1}}f(x_i)dx+\int_{x_{i-1}}^{x_{i+1}}f^{\prime}(x_i)(x-x_i)dx+\int_{x_{i-1}}^{x_{i+1}}\dfrac{f^{\prime\prime}(x_i)(x-x_i)^2}{2!}dx+\int_{x_{i-1}}^{x_{i+1}}\dfrac{f^{\prime\prime\prime}(x_i)(x-x_i)^3}{3!}dx+\int_{x_{i-1}}^{x_{i+1}}\dfrac{f^{\prime\prime\prime\prime}(x_i)(x-x_i)^4}{4!}dx+\cdots.$$
# We then carry out the integrations to get
# $$\int_{x_{i-1}}^{x_{i+1}}f(x)dx=2hf(x_i)+\dfrac{h^3}{6}f^{\prime\prime}(x_i)+O(h^5).$$
# Substituting the expression for $f(x_i)$ derived earlier, the right-hand side becomes
# $$2h\left(\dfrac{f(x_{i-1})+4f(x_i)+f(x_{i+1})}{6}-\dfrac{h^2}{6}f^{\prime\prime}(x_i)+O(h^4) \right)+\dfrac{h^3}{6}f^{\prime\prime}(x_i)+O(h^5).$$
# which can be rearranged to
# $$\left[\dfrac{h}{3}\left(f(x_{i-1})+4f(x_i)+f(x_{i+1})\right)-\dfrac{h^2}{3}f^{\prime\prime}(x_i)+O(h^5)\right]+\dfrac{h^3}{3}f^{\prime\prime}(x_i)+O(h^5)$$
#
# Canceling and combining the appropriate terms results in the integral expression
# $$\int_{x_{i-1}}^{x_{i+1}}f(x)dx=\dfrac{h}{3}\left(f(x_{i-1})+4f(x_i)+f(x_{i+1})\right)+O(h^5)$$
# Recognizing that $\dfrac{h}{3}\left(f(x_{i-1})+4f(x_i)+f(x_{i+1})\right)$ is exactly the Simpson's Rule approximation for the integral over this subinterval, this equation implies that Simpson's Rule is $O(h^5)$ over a subinterval and $O(h^4)$ over the whole interval. Because the $h^3$ terms cancel out exactly, Simpson's Rule gains another two orders of accuracy!

# %% [markdown]
# **Ex**! Use Simpson's Rule to approximate $\int_0^\pi \sin(x)dx$
#  with $11$ evenly spaced grid points over the whole interval. Compare this value to the exact value of $2$.

# %%
import numpy as np

a = 0
b = np.pi
n = 11
h = (b - a) / (n - 1)
x = np.linspace(a, b, n)
f = lambda s: np.sin(s)

I_simp = (h/3) * (f(x[0]) + 2*sum(f(x[2:n-2:2])) + 4*sum(f(x[1:n-1:2])) + f(x[n-1]))
err_simp = 2 - I_simp

print(I_simp)
print(err_simp)
# Out:
# 2.0001095173150043
# -0.00010951731500430384

# %%
# Or we can define f as an array

# %%
import numpy as np

a = 0
b = np.pi
n = 11
h = (b - a) / (n - 1)
x = np.linspace(a, b, n)
f = np.sin(x)

I_simp = (h/3) * (f[0] + 2*sum(f[2:n-2:2]) + 4*sum(f[1:n-1:2]) + f[n-1])
err_simp = 2 - I_simp

print(I_simp)
print(err_simp)
# Out:
# 2.0001095173150043
# -0.00010951731500430384

# %% [markdown]
# **Computing Integrals in Python**
#
# The $\verb|scipy.integrate|$ sub-package has several functions for computing integrals. The $\verb|trapezoid|$ function takes as input arguments an array of function values $f$ computed on a numerical grid $x$.

# %% [markdown]
# **Ex**! Use the $\verb|trapezoid|$ function to approximate $\int_0^\pi \sin(x)dx$
#  for $11$ equally spaced points over the whole interval. Compare this value to the one computed in the early example using the Trapezoid Rule.

# %%
import numpy as np
from scipy.integrate import trapezoid

a = 0
b = np.pi
n = 11
h = (b - a) / (n - 1)
x = np.linspace(a, b, n)
f = np.sin(x)

I_trapezoid = trapezoid(f,x)
I_trap = (h/2)*(f[0] + 2 * sum(f[1:n-1]) + f[n-1])

print(I_trapezoid)
print(I_trap)
# Out:
# 1.9835235375094544
# 1.9835235375094546

# %% [markdown]
# Sometimes we want to know the approximated cumulative integral. That is, we want to know $F(X)=\int_{x_{0}}^{X}f(x)dx$. For this purpose, it is useful to use  the $\verb|cumtrapz|$ function $\verb|cumsum|$ which takes the same input arguments as $\verb|trapezoid|$

# %% [markdown]
# **Ex:**
#
# Use the $\verb|cumulative_trapezoid|$ function to approximate the cumulative integral of $f(x)=\sin(x)$ from $0$ to $\pi$ with a discretization step of $.01$. The exact solution of this integral is $F(x)=-\cos(x)$. Plot the results.

# %%
import matplotlib.pyplot as plt
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
from scipy.integrate import cumulative_trapezoid
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')

x = np.arange(0, np.pi, 0.01)
F_exact = -np.cos(x)
F_approx = cumulative_trapezoid(np.sin(x), x)

plt.figure(figsize = (10,6))
plt.plot(x, F_exact)
plt.plot(x[1::], F_approx)
plt.grid()
plt.tight_layout()
plt.title('$F(x) = \int_0^{x} sin(y) dy$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(['Exact with Offset', 'Approx'])
plt.show()

# %% [markdown]
# The $\verb|quad(f,a,b)|$ function uses a different numerical differentiation scheme to approximate integrals. $\verb|quad(f,a,b)|$ integrates the function defined by the function object, $f$, from $a$ to $b$.

# %% [markdown]
# **Ex:**
# Use the $\verb|integrate.quad|$ function to compute $\int_{0}^{\pi}\sin(x)dx$.  Compare your answer with the correct answer of $2$.

# %%
from scipy.integrate import quad

I_quad, est_err_quad = quad(np.sin, 0, np.pi)
print(I_quad)
err_quad = 2 - I_quad
print(est_err_quad, err_quad)
# Out:
# 2.0
# 2.220446049250313e-14 0.0
