# %%
# Exceptions
# Basics
x = 7
y = 0
z = x/y # ZeroDivisionError
print("Hello")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-061c39149bae> in <cell line: 0>()
#       3 x = 7
#       4 y = 0
# ----> 5 z = x/y # ZeroDivisionError
#       6 print("Hello")
#
# ZeroDivisionError: division by zero

# %%
# How to avoid the program crashing
# Use try/except
x = 7
y = 0
try:
  z = x/y # ZeroDivisionError
except ZeroDivisionError:
  print("Calculation error")
print("Hello")
# Out:
# Calculation error
# Hello

# %%
# Use x = 0
x = int(input("Enter a number: "))
print(5/x)
# Out:
# Enter a number: 2
# 2.5

# %%
# Use x = u
x = int(input("Enter a number: "))
print(5/x)
# Out:
# Enter a number: 3
# 1.6666666666666667

# %%
# Use x = decimal number say 3.14
x = int(input("Enter a number: "))
print(5/x)
# Out:
# Enter a number: 3.14
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-d843d5b6094a> in <cell line: 0>()
#       1 # Use x = decimal number say 3.14
# ----> 2 x = int(input("Enter a number: "))
#       3 print(5/x)
#
# ValueError: invalid literal for int() with base 10: '3.14'

# %%
# Different possibilities for try/except to avoid the program crashing
try:
  x = int(input("Enter a number: "))
  print(5/x)
except ValueError:
  print("Please enter an integer")
except ZeroDivisionError:
  print("Cannot enter zero")
# Out:
# Enter a number: 3.13
# Please enter an integer

# %%
# Not specifying the exception
# You can leave off the name of the exception
try:
  x = int(input("Enter a number: "))
  print(5/x)
except:
  print("A problem has occured")
# Out:
# Enter a number: 0
# A problem has occured

# %%
# Using the exception object
# When you catch an exception, information about
# the exception is stored in an Exception object
try:
  z = 7/0
except Exception as error:
  print(error)
# Out:
# division by zero

# %%
try:
  z = int("7.89")
except Exception as error:
  print(error)
# Out:
# invalid literal for int() with base 10: '7.89'

# %%
try:
  z = int("u")
except Exception as error:
  print(error)
# Out:
# invalid literal for int() with base 10: 'u'

# %%
# FileNotFoundError
f = open("file.txt")
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-b1dc68bd0bec> in <cell line: 0>()
#       1 # FileNotFoundError
# ----> 2 f = open("file.txt")
#       3 f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file.txt'

# %%
# Try/except/else
try:
  f = open("file.txt")
except FileNotFoundError: # can also use IOError: Input/Output exception
  print("Could not find file")
else:
  s = f.read()
  print(s)
# Out:
# Could not find file

# %%
# Try/except/else
try:
  f = open("file.txt")
except Exception as error:
  print(error)
else:
  s = f.read()
  print(s)
# Out:
# [Errno 2] No such file or directory: 'file.txt'

# %%
# We can also use IOError: Input/Output exception
# Try/except/else
try:
  f = open("file.txt")
except IOError as error:
  print(error)
else:
  s = f.read()
  print(s)
# Out:
# [Errno 2] No such file or directory: 'file.txt'

# %%
# try/except/finally
# Things in the finally block are things that must be executed
# whether or not an exception occurs
'''try:
    # code that may cause exceptions
except:
    # code that handles exceptions
finally:
    # code that always executes
'''
# Note
"""
The finally clause always executes whether an exception occurs or not
 and it executes after the try clause and any except clause.
"""

# %%
# Writing to a file
f = open("filename.txt","w")
try:
  z =3/0
except Exception as e:
  print(e,file=f)
finally:
  f.close()

# %%
# Note:
# The finally block can be used along with except and else blocks

# Exception handling with try, except, else, and finally
# Try: This block will test the excepted error to occur
# Except:  Here you can handle the error
# Else: If there is no exception then this block will be executed
# Finally: Finally block always gets executed either exception is generated or not

# %%
"""
Syntax:

try:
       # Some Code....

except:
       # optional block
       # Handling of exception (if required)

else:
       # execute if no exception (ie if exception is not triggered)

finally:
      # Some code .....(always executed)
"""

# %%
# NameError
s=s+2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-d2b7a456d207> in <cell line: 0>()
#       1 # NameError
# ----> 2 s=s+2
#
# NameError: name 's' is not defined

# %%
#Example
try:
  s = s + 2
except:
  s = 2 - 3
finally:
  print("Do something else with s which equals",s)
# Out:
# Do something else with s which equals -1

# %%
try:
  w = w + 2
except:
  w = 7
else:
  w+=11
finally:
  print("Do something else with w which equals",w)
# Out:
# Do something else with w which equals 7

# %%
# What would be the value of w if
# the above is run a second time?
# Ans= ?

# %%
try:
  v = 3 + 2
except:
  v = 7 - 9
else:
  v+=11
finally:
  print("Do something else with t which equals",v)
# Out:
# Do something else with t which equals 16

# %%
#Validating user input as an integer (Integer)

def inputInteger(message):
  while True:
    try:
       userInput = int(input(message))
    except ValueError:
       print("Not an integer! Try again.")
       continue
    else:
       return userInput
       break

inputInteger("Enter an integer: ")
# Out:
# Enter an integer: 2
# 2

# %%
#Validating user input as a number (Floating point number)

def inputNumber(message):
  while True:
    try:
       userInput = float(input(message))
    except ValueError:
       print("Not a number! Try again.")
       continue
    else:
       return userInput
       break

inputNumber("Enter a number: ")
# Out:
# Enter a number: 3
# 3.0

# %%
# Ex:
s = """Anna is 7 years old, and her sister Olivia is 2 years old.
Evelyn and Paul, their parents, have 3 kids."""
# Find the names in the string s
# import re
# re.findall(r'',s)
