# %%
#1
def triangular(n):
  return n*(n+1)/2

# %%
k = int(input("Enter an integer: "))
print(triangular(k))
# Out:
# Enter an integer: 12
# 78.0

# %%
#2
def get_bill_total(bill_am,sale_tax):
  amount=bill_am*(1+sale_tax/100)
  return float("{:.2f}".format(amount))

# %%
bill=float(input("Enter bill amount: "))
tax = float(input("Enter sale tax between 0 and 100: "))
while not(0<=tax<=100):
  print(tax,"must be between 0 and 100")
  tax = float(input("Enter sale tax: "))
print(get_bill_total(bill,tax))
# Out:
# Enter bill amount: 12
# Enter sale tax between 0 and 100: 6
# 12.72

# %%
#3
def print_perfect_squares(k):
  for p in range(1,k+1):
    if p*p <=k:
      print(p*p, end=" ")

# %%
num = int(input("Enter an integer: "))
print_perfect_squares(num)
# Out:
# Enter an integer: 2
# 1

# %%
#4
def add_up_range(num1,num2,num3):
  return sum(list(range(num1,num2,num3)))

# %%
start_loc=int(input("Enter starting location: "))
end_loc = int(input("Enter end location: "))
step = int(input("Enter step: "))
print(add_up_range(start_loc,end_loc,step))
# Out:
# Enter starting location: 1
# Enter end location: 7
# Enter step: 2
# 9

# %%
#4 OR
def add_up_range_1(num1,num2,num3):
  tot =0
  for num in range(num1,num2,num3):
    tot+=num
  return tot

# %%
start_loc=int(input("Enter starting location: "))
end_loc = int(input("Enter end location: "))
step = int(input("Enter step: "))
print(add_up_range_1(start_loc,end_loc,step))
# Out:
# Enter starting location: 1
# Enter end location: 90
# Enter step: 2
# 2025

# %%
#5

def phi(k):
  from math import gcd
  count=0
  if k==0:
    return "Please enter a not null integer!"
  if k==1:
    return 0
  for p in range(1,k+1):
    if gcd(p,k)==1:
      count+=1
  return count

# %%
num = int(input("Enter num: "))
print(phi(num))
# Out:
# Enter num: 12
# 4

# %%
#6
def is_upper(stg):
  if stg==stg.upper():
    return "Every letter of the string is uppercase."
  else:
    return "There is a letter that is not uppercase."

string=input("Enter a string of letters: ")
while not(string.isalpha()):
  print("String must be all letters")
  string=input("Enter a string of letters: ")

is_upper(string)
# Out:
# Enter a string of letters: Hello
# 'There is a letter that is not uppercase.'

# %%
#7 If we want possible repeated characters
def rand_lower_string(k):
  from string import ascii_lowercase
  from random import choice
  s=ascii_lowercase
  return "".join([choice(s) for l in range(k)])

# %%
num=int(input("Enter an integer: "))
print(rand_lower_string(num))
# Out:
# Enter an integer: 2
# lt

# %%
#7 If we want distinct characters
def rand_lower_string1(k):
  from string import ascii_lowercase
  from random import sample
  s=ascii_lowercase
  return "".join(sample(list(s),k))

# %%
num=int(input("Enter an integer: "))
print(rand_lower_string1(num))
# Out:
# Enter an integer: 12
# hgatkcwxqldo

# %%
#8
def simplify_text(stg):
  from string import punctuation
  stg=stg.lower()
  for c in "'-":
    punctuation=punctuation.replace(c,"")
  for char in punctuation:
    stg=stg.replace(char,"")
  return stg

# %%
string = input("Enter a string: ")
print(simplify_text(string))
# Out:
# Enter a string: I can not
# i can not

# %%
#9
def  average(L):
  return float("{:.2f}".format(sum(L)/len(L)))

# %%
num=int(input("Enter number of items in list: "))
list_num = [float(input("Enter numbers: ")) for k in range(num)]
print(average(list_num))
# Out:
# Enter number of items in list: 12
# Enter numbers: 1
# Enter numbers: 2
# Enter numbers: 3
# Enter numbers: 4
# Enter numbers: 5
# Enter numbers: 6
# Enter numbers: 2
# Enter numbers: 3
# Enter numbers: 5
# Enter numbers: 8
# Enter numbers: 7
# Enter numbers: 1
# 3.92

# %%
#10
def string_sort(stg):
  L=list(stg)
  L.sort()
  return "".join(L)

# %%
string=input("Enter string: ")
string=string.lower()
while not(string.isalpha()):
  print("String must be all letters.")
  string=input("Enter string: ")

print(string_sort(string))
# Out:
# Enter string: hi
# hi

# %%
#11
def integer_lengths(L):
  return sum([len(str(item)) for item in L])

# %%
1num=int(input("Enter number of items in list: "))
list_integers=[int(input("Enter an integer: ")) for k in range(num)]
print(integer_lengths(list_integers))
# Out:
# Enter number of items in list: 12
# Enter an integer: 1
# Enter an integer: 1
# Enter an integer: 1
# Enter an integer: 1
# Enter an integer: 1
# Enter an integer: 6
# Enter an integer: 7
# Enter an integer: 98
# Enter an integer: 3
# Enter an integer: 2
# Enter an integer: 1
# Enter an integer: 1
# 13

# %%
#12
def union(L1,L2):
  Union=[]
  L1.extend(L2)
  for item in L1:
    if item not in Union:
      Union.append(item)
  return Union

# %%
num1 = int(input("Enter number of elements in the first list: "))
List1 = [input("Enter elements of list 1: ") for k in range(num1)]

num2 = int(input("Enter number of elements in the second list: "))
List2 = [input("Enter elements of list 2: ") for k in range(num2)]

print(List1)
print(List2)
print(union(List1,List2))
# Out:
# Enter number of elements in the first list: 2
# Enter elements of list 1: 1
# Enter elements of list 1: 2
# Enter number of elements in the second list: 3
# Enter elements of list 2: 4
# Enter elements of list 2: `
# Enter elements of list 2: 3
# ['1', '2']
# ['4', '`', '3']
# ['1', '2', '4', '`', '3']

# %%
#13

def words_in_word(stg):
  with open("/content/wordlist.txt") as f:
    lines=[line.rstrip() for line in f]

    result=[]
    for w in lines:
      if w in stg:
        result.append(w)
  return result

# %%
string=input("Enter a string: ")
print(words_in_word(string))
# Out:
# Enter a string: hi
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-9cfb9034bdd5> in <cell line: 0>()
#       1 string=input("Enter a string: ")
# ----> 2 print(words_in_word(string))
#
# <ipython-input-31-5d783bd7cb8f> in words_in_word(stg)
#       2
#       3 def words_in_word(stg):
# ----> 4   with open("/content/wordlist.txt") as f:
#       5     lines=[line.rstrip() for line in f]
#       6
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/wordlist.txt'

# %%
#14
def changes_by_one(L):
  result=[]
  for k in range(len(L)-1):
    if L[k+1]-L[k]==1:
      result.append(k+1)
  return result

# %%
num=int(input("Number of items in list: "))
num_list=[int(input("Enter a number: ")) for k in range(num)]
print(changes_by_one(num_list))
# Out:
# Number of items in list: 2
# Enter a number: 34
# Enter a number: 54
# []

# %%
#14
def changes_by_one1(L):
  return [k+1 for k in range(len(L)-1) if L[k+1]-L[k]==1]

# %%
num=int(input("Number of items in list: "))
num_list=[int(input("Enter a number: ")) for k in range(num)]
print(changes_by_one1(num_list))
# Out:
# Number of items in list: 2
# Enter a number: 1
# Enter a number: 6
# []

# %%
def changes_by_one2(L):
  return [k for k in range(1,len(L)) if L[k]-L[k-1]==1]

n = int(input("Enter number of elements in the first list: "))
num_List = [int(input("Enter numbers: ")) for k in range(n)]

print(changes_by_one2(num_List))
# Out:
# Enter number of elements in the first list: 2
# Enter numbers: 1
# Enter numbers: 3
# []
